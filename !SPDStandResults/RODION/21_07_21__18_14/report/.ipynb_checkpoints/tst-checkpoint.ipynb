# %%
import pandas as pd

df = pd.read_csv("optimization_table.csv")
df
# Out:
#      Unnamed: 0     t         vb      vg    qe         dcr     dt        ap  \
# 0             0 -50.0  74.545570     0.0   5.0   90.801318  6.135  0.161668
# 1             1 -50.0  74.607344   100.0   5.0  122.941880  6.065  0.183194
# 2             2 -50.0  74.261589   200.0   5.0   95.229954  6.220  0.106311
# 3             3 -50.0  73.800836   300.0   5.0   39.621266  5.985  0.059638
# 4             4 -50.0  73.599166   400.0   5.0   53.592218  5.920  0.173222
# ..          ...   ...        ...     ...   ...         ...    ...       ...
# 358         358 -40.0  74.538763   600.0  15.0  427.678931  3.855  0.459578
# 359         359 -40.0  74.189421   700.0  15.0  366.335512  6.335  0.458757
# 360         360 -40.0  74.104833   800.0  15.0  444.363676  5.910  0.663156
# 361         361 -40.0  73.767485   900.0  15.0  356.599344  6.130  0.376659
# 362         362 -40.0  73.516781  1000.0  15.0  290.004105  3.915  0.126202
#
#           bif
# 0    3.607539
# 1    3.062140
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 't', 'vb', 'vg', 'qe', 'dcr', 'dt', 'ap', 'bif'], dtype='object')
